# %%
import snowflake.ml.modeling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import snowflake.ml.modeling
#
# ModuleNotFoundError: No module named 'snowflake.ml'

# %%
from snowflake.snowpark.session import Session
connection_params = {'user': 'ANKIT', 'password': 'Ankit@123', 'account': 'rwb76633.prod3.us-west-2.aws', 'database': 'MLOPS_SPCS', 'schema': 'SPCS_SCHEMA', 'role': 'MLOPS_COE_ROLE', 'warehouse': 'MLOPS_WAREHOUSE'}

# %%
session = Session.builder.configs(connection_params).create()
# Out:
# ---------------------------------------------------------------------------
# LibraryNotFoundError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 session = Session.builder.configs(connection_params).create()
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/session.py:232, in Session.SessionBuilder.create(self)
#     230 if "connection" in self._options:
#     231     return self._create_internal(self._options["connection"])
# --> 232 return self._create_internal(conn=None)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/session.py:238, in Session.SessionBuilder._create_internal(self, conn)
#     234 def _create_internal(
#     235     self, conn: Optional[SnowflakeConnection] = None
#     236 ) -> "Session":
#     237     new_session = Session(
# --> 238         ServerConnection({}, conn) if conn else ServerConnection(self._options)
#     239     )
#     240     if "password" in self._options:
#     241         self._options["password"] = None
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:138, in ServerConnection.__init__(self, options, conn)
#     136 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     137 self._add_application_name()
# --> 138 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     139 if "password" in self._lower_case_parameters:
#     140     self._lower_case_parameters["password"] = None
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/__init__.py:51, in Connect(**kwargs)
#      50 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 51     return SnowflakeConnection(**kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/connection.py:302, in SnowflakeConnection.__init__(self, **kwargs)
#     300 self.converter = None
#     301 self.__set_error_attributes()
# --> 302 self.connect(**kwargs)
#     303 self._telemetry = TelemetryClient(self._rest)
#     305 # get the imported modules from sys.modules
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/connection.py:566, in SnowflakeConnection.connect(self, **kwargs)
#     564         connection_diag.generate_report()
#     565 else:
# --> 566     self.__open_connection()
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/connection.py:819, in SnowflakeConnection.__open_connection(self)
#     815 else:
#     816     # okta URL, e.g., https://<account>.okta.com/
#     817     self.auth_class = AuthByOkta(application=self.application)
# --> 819 self.authenticate_with_retry(self.auth_class)
#     821 self._password = None  # ensure password won't persist
#     822 self.auth_class.reset_secrets()
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/connection.py:1075, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1072 def authenticate_with_retry(self, auth_instance):
#    1073     # make some changes if needed before real __authenticate
#    1074     try:
# -> 1075         self._authenticate(auth_instance)
#    1076     except ReauthenticationRequest as ex:
#    1077         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1078         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/connection.py:1096, in SnowflakeConnection._authenticate(self, auth_instance)
#    1094 auth = Auth(self.rest)
#    1095 try:
# -> 1096     auth.authenticate(
#    1097         auth_instance=auth_instance,
#    1098         account=self.account,
#    1099         user=self.user,
#    1100         database=self.database,
#    1101         schema=self.schema,
#    1102         warehouse=self.warehouse,
#    1103         role=self.role,
#    1104         passcode=self._passcode,
#    1105         passcode_in_password=self._passcode_in_password,
#    1106         mfa_callback=self._mfa_callback,
#    1107         password_callback=self._password_callback,
#    1108         session_parameters=self._session_parameters,
#    1109     )
#    1110 except OperationalError as e:
#    1111     logger.debug(
#    1112         "Operational Error raised at authentication"
#    1113         f"for authenticator: {type(auth_instance).__name__}"
#    1114     )
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/auth/_auth.py:250, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     247 logger.debug(f"Timeout set to {auth_timeout}")
#     249 try:
# --> 250     ret = self._rest._post_request(
#     251         url,
#     252         headers,
#     253         json.dumps(body),
#     254         timeout=auth_timeout,
#     255         socket_timeout=auth_timeout,
#     256     )
#     257 except ForbiddenError as err:
#     258     # HTTP 403
#     259     raise err.__class__(
#     260         msg=(
#     261             "Failed to connect to DB. "
#    (...)
#     268         sqlstate=SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     269     )
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:704, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout, _include_retry_params)
#     701     ret = probe_connection(full_url)
#     702     pprint(ret)
# --> 704 ret = self.fetch(
#     705     "post",
#     706     full_url,
#     707     headers,
#     708     data=body,
#     709     timeout=timeout,
#     710     token=token,
#     711     no_retry=no_retry,
#     712     socket_timeout=socket_timeout,
#     713     _include_retry_params=_include_retry_params,
#     714 )
#     715 logger.debug(
#     716     "ret[code] = {code}, after post request".format(
#     717         code=(ret.get("code", "N/A"))
#     718     )
#     719 )
#     721 if ret.get("code") == SESSION_EXPIRED_GS_CODE:
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:802, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     800 retry_ctx = RetryCtx(timeout, include_retry_params)
#     801 while True:
# --> 802     ret = self._request_exec_wrapper(
#     803         session, method, full_url, headers, data, retry_ctx, **kwargs
#     804     )
#     805     if ret is not None:
#     806         return ret
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:925, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     923 except Exception as e:
#     924     if not no_retry:
# --> 925         raise e
#     926     logger.debug("Ignored error", exc_info=True)
#     927     return {}
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:845, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     843 full_url = SnowflakeRestful.add_request_guid(full_url)
#     844 try:
# --> 845     return_object = self._request_exec(
#     846         session=session,
#     847         method=method,
#     848         full_url=full_url,
#     849         headers=headers,
#     850         data=data,
#     851         token=token,
#     852         **kwargs,
#     853     )
#     854     if return_object is not None:
#     855         return return_object
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:1124, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#    1114 except Exception as err:
#    1115     TelemetryService.get_instance().log_http_request_error(
#    1116         "HttpException%s" % str(err),
#    1117         full_url,
#    (...)
#    1122         stack_trace=traceback.format_exc(),
#    1123     )
# -> 1124     raise err
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/network.py:1026, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout)
#    1022 download_start_time = get_time_millis()
#    1023 # socket timeout is constant. You should be able to receive
#    1024 # the response within the time. If not, ConnectReadTimeout or
#    1025 # ReadTimeout is raised.
# -> 1026 raw_ret = session.request(
#    1027     method=method,
#    1028     url=full_url,
#    1029     headers=headers,
#    1030     data=input_data,
#    1031     timeout=socket_timeout,
#    1032     verify=True,
#    1033     stream=is_raw_binary,
#    1034     auth=SnowflakeAuth(token),
#    1035 )
#    1036 download_end_time = get_time_millis()
#    1038 try:
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/ssl_wrap_socket.py:78, in ssl_wrap_socket_with_ocsp(*args, **kwargs)
#      74     kwargs["ca_certs"] = certifi.where()
#      76 ret = ssl_.ssl_wrap_socket(*args, **kwargs)
# ---> 78 from .ocsp_asn1crypto import SnowflakeOCSPAsn1Crypto as SFOCSP
#      80 log.debug(
#      81     "OCSP Mode: %s, " "OCSP response cache file name: %s",
#      82     FEATURE_OCSP_MODE.name,
#      83     FEATURE_OCSP_RESPONSE_CACHE_FILE_NAME,
#      84 )
#      85 if FEATURE_OCSP_MODE != OCSPMode.INSECURE:
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/ocsp_asn1crypto.py:60
#      55         if _module_values["backend"] is None:
#      56             use_openssl(
#      57                 libcrypto_path="/usr/lib/libcrypto.35.dylib",
#      58                 libssl_path="/usr/lib/libssl.35.dylib",
#      59             )
# ---> 60     from oscrypto import asymmetric
#      63 logger = getLogger(__name__)
#      66 class SnowflakeOCSPAsn1Crypto(SnowflakeOCSP):
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/asymmetric.py:19
#       7 from . import backend
#       8 from ._asn1 import (
#       9     armor,
#      10     Certificate as Asn1Certificate,
#    (...)
#      17     PublicKeyInfo,
#      18 )
# ---> 19 from ._asymmetric import _unwrap_private_key_info
#      20 from ._errors import pretty_message
#      21 from ._types import type_name, str_cls
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/_asymmetric.py:27
#       7 import binascii
#       9 from ._asn1 import (
#      10     CertBag,
#      11     Certificate,
#    (...)
#      24     unarmor,
#      25 )
# ---> 27 from .kdf import pbkdf1, pbkdf2, pkcs12_kdf
#      28 from .symmetric import (
#      29     aes_cbc_pkcs7_decrypt,
#      30     des_cbc_pkcs5_decrypt,
#    (...)
#      33     tripledes_cbc_pkcs5_decrypt,
#      34 )
#      35 from .util import constant_compare
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/kdf.py:9
#       6 from datetime import datetime
#       8 from . import backend
# ----> 9 from .util import rand_bytes
#      10 from ._types import type_name, byte_cls, int_types
#      11 from ._errors import pretty_message
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/util.py:14
#      12     from ._win.util import rand_bytes
#      13 else:
# ---> 14     from ._openssl.util import rand_bytes
#      17 __all__ = [
#      18     'constant_compare',
#      19     'rand_bytes',
#      20 ]
#      23 def constant_compare(a, b):
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/_openssl/util.py:6
#       4 from .._errors import pretty_message
#       5 from .._ffi import buffer_from_bytes, bytes_from_buffer
# ----> 6 from ._libcrypto import libcrypto, libcrypto_version_info, handle_openssl_error
#       7 from .._rand import rand_bytes
#       8 from .._types import type_name, byte_cls, int_types
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/_openssl/_libcrypto.py:9
#       6 from .._types import str_cls
#       8 if ffi() == 'cffi':
# ----> 9     from ._libcrypto_cffi import (
#      10         libcrypto,
#      11         version as libcrypto_version,
#      12         version_info as libcrypto_version_info
#      13     )
#      14 else:
#      15     from ._libcrypto_ctypes import (
#      16         libcrypto,
#      17         version as libcrypto_version,
#      18         version_info as libcrypto_version_info
#      19     )
#
# File /opt/conda/lib/python3.8/site-packages/oscrypto/_openssl/_libcrypto_cffi.py:44
#      42     version_match = re.search('(?<=LibreSSL )(\\d\\.\\d(\\.\\d)?)\\b', version_string)
#      43 if not version_match:
# ---> 44     raise LibraryNotFoundError('Error detecting the version of libcrypto')
#      45 version = version_match.group(1)
#      46 version_parts = re.sub('(\\d)([a-z]+)', '\\1.\\2', version).split('.')
#
# LibraryNotFoundError: Error detecting the version of libcrypto

# %%
query = "show services;"
data = session.sql(query).collect()
for item in data:
    print(item.as_dict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 query = "show services;"
# ----> 2 data = session.sql(query).collect()
#       3 for item in data:
#       4     print(item.as_dict())
#
# NameError: name 'session' is not defined

# %%
session.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 session.close()
#
# NameError: name 'session' is not defined
